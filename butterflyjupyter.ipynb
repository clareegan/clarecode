# %% [markdown]
# importing CSV files from desktop

# %%
import pandas as pd

# %% [markdown]
# importing first data fram CSV files from Monarch Watch

# %%
df1 = pd.read_csv ("Inputs/Monarch Watch 2021 Season Tag Recoveries - Domestic - domestic-recoveries-2021.csv")
df1
# Out:
#      Tag Code      Date        City/Location State/Province   ZIP/PC Country  \
# 0     AAHW467   9/12/21              Toronto             ON   M1L3G3     CAN
# 1     AAHW481   8/14/21              Toronto             ON  M4K 2K1     CAN
# 2     AAHW486   8/14/21              Toronto             ON   M4K2H9     CAN
# 3     AAHW493   8/19/21              Toronto             ON  M4M 2E2     CAN
# 4     AAHW494   8/19/21  East York (Toronto)             ON  M4J 2Y7     CAN
# ...       ...       ...                  ...            ...      ...     ...
# 1083   PHZ765  10/21/21          San Antonio             TX    78204     USA
# 1084   TGZ150    9/7/21            St joseph             MO    64505     USA
# 1085   UMA204  10/16/21          San Antonio             TX    78204     USA
# 1086   WMH322   9/15/21             Bluffton             SC    29910     USA
# 1087   YYX823   9/12/21          Catonsville             MD    21228     USA
#
#      First Name                                              Notes
# 0         Emily      Found on our butterfly bush outside our house
# 1       Melissa                                                NaN
# 2         Peter                                                NaN
# 3       Sheldon               Downtown front yard - butterfly bush
# 4     Christine  We noticed the monarch in our garden at 10am, ...
# ...         ...                                                ...
# 1083        Lee  feeding on Gregg's Mistflower in a pollinator ...
# 1084     Ronald                    On a flower in my flower garden
# 1085  Savannnah  Found in grandparents backyard on a Barbados p...
# 1086     Mercia        At my home on the milkweed. Tag dropped off
# 1087      Sarah  Found in our white Joe Pye Weed in the front yard
#
# [1088 rows x 8 columns]

# %%
df2 = pd.read_csv("Inputs//Monarch Watch 2022 Season Tag Recoveries - Domestic - domestic-recoveries-2022.csv")
df2
# Out:
#     Tag Code      Date City/Location State/Province  ZIP/PC Country  \
# 0    AAAF203   11/7/22       Killeen             TX   76542     USA
# 1    AACW276   8/29/22        Duluth             MN   55802     USA
# 2    AACW276   8/31/22        Duluth             MN   55802     USA
# 3    AACW276    9/5/22        Duluth             MN   55802     USA
# 4    AANR121   8/25/22        Burton             MI   48506     USA
# ..       ...       ...           ...            ...     ...     ...
# 857  AHBC854  10/29/22       Cypress             TX   77433     USA
# 858   GXX638   10/2/22         Tulsa             OK   74114     USA
# 859   UMT629    9/1/22       Raleigh             NC   27607     USA
# 860   WBT932   9/10/22    Hagerstown             MD   21742     USA
# 861   YUB708    9/3/22       Toronto             ON  M6k3c3     CAN
#
#     First Name                                              Notes
# 0         Paul   This monarch was with 3 other I tagged monarchs.
# 1      Breanna  Spotted on flowers in local park that has purp...
# 2       Deanna  A Zen garden area in the downtown area on a Hy...
# 3          Kim  On a native plant garden near Canal Brewing Co...
# 4      Gregory               Formar Nature Preserve in Burton MI.
# ..         ...                                                ...
# 857       Dana  The monarch was found in mulch moving but it c...
# 858     Montez  Beautiful fresh looking monarch. Nectaring on ...
# 859       Jeff  Butterfly garden, NCSM Prairie Ridge Ecostatio...
# 860      Lukas  The butterfly had a damaged wing, I placed it ...
# 861       Erin                   Nectaring on some butterfly bush
#
# [862 rows x 8 columns]

# %%
df3 = pd.read_csv("Inputs//Monarch Watch Tag Recoveries - Central Mexico - mexico-recoveries.csv")
years_to_match = [2022, 2021]
df3_filtered = df3[df3['Report Season'].isin(years_to_match)]
df3_filtered
# Out:
#      Tag Code  Report Season        Location
# 0     AACT584           2022      El Rosario
# 1     AAHP562           2022      El Rosario
# 2     AANY296           2022      El Rosario
# 3     AAPW156           2022      El Rosario
# 4     AARG636           2022     Cerro Pelon
# ...       ...            ...             ...
# 1259   YSE236           2021      El Rosario
# 1260   YSX692           2021      El Rosario
# 1261   YYJ835           2021  Sierra Chincua
# 1262   YYJ913           2021  Sierra Chincua
# 1263   ZAR016           2021  Sierra Chincua
#
# [1264 rows x 3 columns]

# %%
df3_filtered = df3[df3['Report Season'].isin(years_to_match)]
df3_filtered.rename(columns={'Report Season':'Years'}, inplace= True)
df3_filtered
# Out:
# /tmp/ipykernel_40621/2736797259.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3_filtered.rename(columns={'Report Season':'Years'}, inplace= True)
#      Tag Code  Years        Location
# 0     AACT584   2022      El Rosario
# 1     AAHP562   2022      El Rosario
# 2     AANY296   2022      El Rosario
# 3     AAPW156   2022      El Rosario
# 4     AARG636   2022     Cerro Pelon
# ...       ...    ...             ...
# 1259   YSE236   2021      El Rosario
# 1260   YSX692   2021      El Rosario
# 1261   YYJ835   2021  Sierra Chincua
# 1262   YYJ913   2021  Sierra Chincua
# 1263   ZAR016   2021  Sierra Chincua
#
# [1264 rows x 3 columns]

# %% [markdown]
# Combining both datasets!

# %%
df4 = pd.concat([df1, df2, df3_filtered])
df4.rename(columns={'City/Location':'Location'}, inplace= True)
df4
# Out:
#      Tag Code     Date             Location State/Province   ZIP/PC Country  \
# 0     AAHW467  9/12/21              Toronto             ON   M1L3G3     CAN
# 1     AAHW481  8/14/21              Toronto             ON  M4K 2K1     CAN
# 2     AAHW486  8/14/21              Toronto             ON   M4K2H9     CAN
# 3     AAHW493  8/19/21              Toronto             ON  M4M 2E2     CAN
# 4     AAHW494  8/19/21  East York (Toronto)             ON  M4J 2Y7     CAN
# ...       ...      ...                  ...            ...      ...     ...
# 1259   YSE236      NaN                  NaN            NaN      NaN     NaN
# 1260   YSX692      NaN                  NaN            NaN      NaN     NaN
# 1261   YYJ835      NaN                  NaN            NaN      NaN     NaN
# 1262   YYJ913      NaN                  NaN            NaN      NaN     NaN
# 1263   ZAR016      NaN                  NaN            NaN      NaN     NaN
#
#      First Name                                              Notes   Years  \
# 0         Emily      Found on our butterfly bush outside our house     NaN
# 1       Melissa                                                NaN     NaN
# 2         Peter                                                NaN     NaN
# 3       Sheldon               Downtown front yard - butterfly bush     NaN
# 4     Christine  We noticed the monarch in our garden at 10am, ...     NaN
# ...         ...                                                ...     ...
# 1259        NaN                                                NaN  2021.0
# 1260        NaN                                                NaN  2021.0
# 1261        NaN                                                NaN  2021.0
# 1262        NaN                                                NaN  2021.0
# 1263        NaN                                                NaN  2021.0
#
#             Location
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 1259      El Rosario
# 1260      El Rosario
# 1261  Sierra Chincua
# 1262  Sierra Chincua
# 1263  Sierra Chincua
#
# [3214 rows x 10 columns]

# %%
df5_filtered = df4.dropna(subset=['Years'])
df5_filtered
# Out:
#      Tag Code Date Location State/Province ZIP/PC Country First Name Notes  \
# 0     AACT584  NaN      NaN            NaN    NaN     NaN        NaN   NaN
# 1     AAHP562  NaN      NaN            NaN    NaN     NaN        NaN   NaN
# 2     AANY296  NaN      NaN            NaN    NaN     NaN        NaN   NaN
# 3     AAPW156  NaN      NaN            NaN    NaN     NaN        NaN   NaN
# 4     AARG636  NaN      NaN            NaN    NaN     NaN        NaN   NaN
# ...       ...  ...      ...            ...    ...     ...        ...   ...
# 1259   YSE236  NaN      NaN            NaN    NaN     NaN        NaN   NaN
# 1260   YSX692  NaN      NaN            NaN    NaN     NaN        NaN   NaN
# 1261   YYJ835  NaN      NaN            NaN    NaN     NaN        NaN   NaN
# 1262   YYJ913  NaN      NaN            NaN    NaN     NaN        NaN   NaN
# 1263   ZAR016  NaN      NaN            NaN    NaN     NaN        NaN   NaN
#
#        Years        Location
# 0     2022.0      El Rosario
# 1     2022.0      El Rosario
# 2     2022.0      El Rosario
# 3     2022.0      El Rosario
# 4     2022.0     Cerro Pelon
# ...      ...             ...
# 1259  2021.0      El Rosario
# 1260  2021.0      El Rosario
# 1261  2021.0  Sierra Chincua
# 1262  2021.0  Sierra Chincua
# 1263  2021.0  Sierra Chincua
#
# [1264 rows x 10 columns]

# %%
df5_filtered.to_csv ("Outputs/Recovery.csv")
